# %% [markdown]
# <a href="https://colab.research.google.com/github/vanshikamandala/python-exercise/blob/main/24_05_2022_graphs_matplotib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array(["clad","itp","clang","physics","eng","venture",])
ypoints = np.array([89,69,75,84,76,90])

plt.plot(xpoints, ypoints)
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([1,6,87,5, 8])
ypoints = np.array([3, 10,78,87,6])

plt.plot(xpoints, ypoints, 'o',color='pink')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([1, 8])
ypoints = np.array([3, 10])

plt.plot(xpoints,marker='o',color='yellow')
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([3,6,7,10,13,45])
ypoints = np.array([89,69,75,84,76,90])

plt.plot(xpoints, ypoints)
plt.show()
